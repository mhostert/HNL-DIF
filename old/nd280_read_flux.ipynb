# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
main_folder = 'nd280-heavy-neutrino-search-2018_main/'
flux_filename = 'flux.npy'

# %%
flux = np.load(main_folder+flux_filename)

# %%
masses = np.linspace(140, 490, 36)

# %%
plt.plot(masses, flux[:, 10], label='Mode 10 K → µN → µ(e + e − ν(ν̄) µ,τ )')
plt.plot(masses, flux[:, 14], label='Mode 14 K → µN → µ(e + e − ν(ν̄) e )')
plt.xlabel(r'$M_N$ [MeV]')
plt.ylabel('Flux')
plt.legend(frameon=False)
plt.yscale('log')

# %%
for mode in [0, 4, 10, 12, 18, 22]:
    plt.plot(masses, flux[:, mode], label=f'Mode {mode}')
plt.xlabel(r'$M_N$ [MeV]')
plt.ylabel('Flux')
plt.legend(frameon=False)
plt.yscale('log')

# %%
plt.plot(masses, flux[:, 0]/flux[:, 4], label=f'Mode {mode}')
# Out:
# <ipython-input-8-ac75a5b9849f>:1: RuntimeWarning: invalid value encountered in true_divide
#   plt.plot(masses, flux[:, 0]/flux[:, 4], label=f'Mode {mode}')
